# %%
import numpy as np
import pandas as pd
import networkx as nx
from joblib import dump, load

from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import FactorAnalysis

from tqdm import tqdm, trange
import plotly.express as px
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

# %%
for style in plt.style.available:
    print(style)
plt.style.use('seaborn-paper')
# Out:
# Solarize_Light2
# _classic_test_patch
# bmh
# classic
# dark_background
# fast
# fivethirtyeight
# ggplot
# grayscale
# seaborn
# seaborn-bright
# seaborn-colorblind
# seaborn-dark
# seaborn-dark-palette
# seaborn-darkgrid
# seaborn-deep
# seaborn-muted
# seaborn-notebook
# seaborn-paper
# seaborn-pastel
# seaborn-poster
# seaborn-talk
# seaborn-ticks
# seaborn-white
# seaborn-whitegrid
# tableau-colorblind10

# %%
raw_influence_data = pd.read_csv("influence_data.csv")
m = np.shape(raw_influence_data)[0]
musician_dict = dict()
genre_scale_evolve = pd.DataFrame(np.zeros((n_genres, 9)), index = genres, columns = list(range(1920, 2010, 10)))

for i in range(m):
    g1 = raw_influence_data["influencer_main_genre"][i]
    y1 = (raw_influence_data["influencer_active_start"][i] // 10) * 10
    g2 = raw_influence_data["follower_main_genre"][i]
    y2 = (raw_influence_data["follower_active_start"][i] // 10) * 10
    if musician_dict.get(raw_influence_data["influencer_id"][i], -1) == -1:
        musician_dict[raw_influence_data["influencer_id"][i]] = g1
        if y1 < 2010:
            genre_scale_evolve.loc[g1][y1] += 1
    if musician_dict.get(raw_influence_data["follower_id"][i], -1) == -1:
        musician_dict[raw_influence_data["follower_id"][i]] = g2
        if y2 < 2010:
            genre_scale_evolve.loc[g2][y2] += 1

# %%
info_columns = ["danceability", "energy", "valence", "tempo", "loudness", "mode", "key", "acousticness",
                "instrumentalness", "liveness", "speechiness", "duration_ms"]

raw_full_data = pd.read_csv("full_music_data.csv")
release_dates = []
for date in raw_full_data["release_date"].values:
    year = date.rstrip(' ')[-2:]
    y = int(year)
    if y < 20:
        y = 2000+(y//10)*10
    else:
        y = 1900+(y//10)*10
    release_dates.append(y)
raw_full_data["release_date"] = release_dates

artists_id = raw_full_data["artists_id"].values
genre_list = []
n = np.shape(artists_id)[0]
for i in range(n):
    temp, flag = artists_id[i][1:-1].split(','), False
    for x in temp:
        if musician_dict.get(int(x.lstrip(' ')), -1) != -1:
            genre_list.append(musician_dict[int(x.lstrip(' '))])
            flag = True
            break
    if not flag:
        genre_list.append("Unknown")

genres = pd.unique(genre_list)
n_genres = len(genres)

# %%
raw_data_artist = pd.read_csv("data_by_artist.csv")

scaler = MinMaxScaler()
X = scaler.fit_transform(raw_data_artist[info_columns].values)

dimension_reducer = load("P2_FA.joblib")
Z = dimension_reducer.transform(X)
# Out:
# Index(['artist_name', 'artist_id', 'danceability', 'energy', 'valence',
#        'tempo', 'loudness', 'mode', 'key', 'acousticness', 'instrumentalness',
#        'liveness', 'speechiness', 'duration_ms', 'popularity', 'count'],
#       dtype='object')

# %% [markdown]
# I tried both raw data $X$ and transformed data $XC^T$ whose coefficients $C^T$ are provided by Factor Analysis in Problem 2.
# The result shows that with linear transform by FA, the divergences between genres are larger and within a genre are smaller.

# %%
musician_embedding = dict()
genre_dict = {g: [] for g in genres}

for i in range(np.shape(raw_data_artist)[0]):
    if musician_dict.get(raw_data_artist["artist_id"][i], -1) != -1:
        musician_embedding[raw_data_artist["artist_id"][i]] = Z[i, :]
        genre_dict[musician_dict[raw_data_artist["artist_id"][i]]].append(raw_data_artist["artist_id"][i])

# %%
n_musicians = np.shape(raw_data_artist)[0]

diff = np.zeros((n_musicians, n_musicians))
# print(raw_data_artist["artist_id"].values)
for c in info_columns:
    temp = raw_data_artist[c].values
    for j in trange(n_musicians):
        for k in range(n_musicians):
            diff[j][k] = temp[j] - temp[k]
    df = pd.DataFrame(diff, index = raw_data_artist["artist_id"].values, columns = raw_data_artist["artist_id"].values)
    df.to_csv(c + ".csv")
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5854/5854 [00:22<00:00, 263.32it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5854/5854 [00:23<00:00, 244.94it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5854/5854 [00:23<00:00, 253.77it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5854/5854 [00:22<00:00, 258.19it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5854/5854 [00:23<00:00, 252.14it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5854/5854 [00:24<00:00, 242.68it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5854/5854 [00:24<00:00, 239.65it/s]
#  67%|██████████████████████████████████████████████████████████████████████████████▌                                      | 3933/5854 [00:16<00:07, 245.27it/s]

# %%
if dimension_reducer.n_components == 3:
    fig = plt.figure()
    ax = Axes3D(fig)
else:
    plt.figure()
for g in genres:
    embeddings = []
    for artist, genre in musician_dict.items():
        if genre == g and musician_embedding.get(artist, -1) is not -1:
            embeddings.append(musician_embedding[artist])
    temp = np.array(embeddings)
    if dimension_reducer.n_components == 3:
        ax.scatter3D(temp[:, 0], temp[:, 1], temp[:, 2])
    else:
        x, y = musician_embedding[artist]
        plt.scatter(temp[:, 0], temp[:, 1])
# plt.legends = genres
plt.show()

# %%
# for g1 in tqdm(genres):
similarity_matrix = pd.DataFrame(columns = genres, index = genres, dtype = float)
for g1 in genres:
    for g2 in genres:
        g1_artists, g2_artists = genre_dict[g1], genre_dict[g2]
        g1_embedding, g2_embedding = [], []
        for artist in g1_artists:
            g1_embedding.append(musician_embedding[artist])
        for artist in g2_artists:
            g2_embedding.append(musician_embedding[artist])
        g1_embedding, g2_embedding = np.array(g1_embedding), np.array(g2_embedding)
#       Gaussian similarity
        sim = np.zeros((len(g1_embedding), len(g2_embedding)))
        for i in range(len(g1_embedding)):
            sim[i, :] = np.exp(-np.linalg.norm(g1_embedding[i]-g2_embedding, 2, axis = 1)**2 / 0.18)
        similarity_matrix[g1][g2] = np.mean(sim[:])

#       Cosine similarity
#         g1_norm = np.linalg.norm(g1_embedding, 2, axis = 1, keepdims = True)
#         g2_norm = np.linalg.norm(g2_embedding, 2, axis = 1, keepdims = True)
#         denominator = np.dot(g1_norm, g2_norm.T)
#         similarity_matrix[g1][g2] = np.mean((np.dot(g1_embedding, g2_embedding.T)/denominator)[:])

# %%
fig = px.imshow(similarity_matrix)
fig.show()

# fig, ax = plt.subplots()
# im = ax.imshow(similarity_matrix)
# ax.set_xticks(np.arange(len(genres)))
# ax.set_yticks(np.arange(len(genres)))
# ax.set_xticklabels(genres)
# ax.set_yticklabels(genres)
# plt.setp(ax.get_xticklabels(), rotation=60, ha="right",
#          rotation_mode="anchor")
# cbar = ax.figure.colorbar(im, ax=ax)
# cbar.ax.set_ylabel("", rotation=-90, va="bottom")
# plt.show()
# Out:
# <div>                            <div id="f4ff09b1-b719-42e3-895e-27384804ca15" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4ff09b1-b719-42e3-895e-27384804ca15")) {                    Plotly.newPlot(                        "f4ff09b1-b719-42e3-895e-27384804ca15",                        [{"coloraxis": "coloraxis", "hovertemplate": "x: %{x}<br>y: %{y}<br>color: %{z}<extra></extra>", "name": "0", "type": "heatmap", "x": ["Electronic", "R&B;", "Vocal", "Pop/Rock", "Religious", "Blues", "Country", "Unknown", "Jazz", "Latin", "New Age", "Folk", "International", "Reggae", "Comedy/Spoken", "Easy Listening", "Classical", "Avant-Garde", "Stage & Screen", "Children's"], "xaxis": "x", "y": ["Electronic", "R&B;", "Vocal", "Pop/Rock", "Religious", "Blues", "Country", "Unknown", "Jazz", "Latin", "New Age", "Folk", "International", "Reggae", "Comedy/Spoken", "Easy Listening", "Classical", "Avant-Garde", "Stage & Screen", "Children's"], "yaxis": "y", "z": [[0.8004015223250306, 0.8149459526360705, 0.6011120829188377, 0.8168740150217764, 0.7883191326804109, 0.7330304897324074, 0.7775603589878507, 0.7762816853774321, 0.6384075566268769, 0.773084268626101, 0.470567005304622, 0.6234762182972151, 0.6972383454471798, 0.8051620260551626, 0.7468230002816751, 0.60175927405833, 0.4158100192338548, 0.5415322340371073, 0.512779222231007, 0.7105896444436658], [0.8149459526360705, 0.8872620211841757, 0.6904284211779633, 0.8506516149518881, 0.8470893568138962, 0.827850124900962, 0.8635979389166459, 0.8381155982169706, 0.6997395457434246, 0.8561961392156686, 0.4859371228138632, 0.7169404076512482, 0.778922507153374, 0.877846196114569, 0.8193048065112736, 0.6517093196451332, 0.44330546281755234, 0.5816384827267479, 0.5430795451608215, 0.8355744680889124], [0.6011120829188377, 0.6904284211779631, 0.9132589850290737, 0.613519242707425, 0.7371374775810813, 0.8033723833314276, 0.7506828197141611, 0.6019906158107386, 0.8324913307848212, 0.7165955128149032, 0.7560610088564912, 0.8944861750924208, 0.786970425226873, 0.6158106425077808, 0.8114904244597966, 0.8566445635810802, 0.7954041828507572, 0.75265680763787, 0.8203748683928295, 0.8772003723909857], [0.8168740150217761, 0.8506516149518879, 0.6135192427074248, 0.8463487340855335, 0.8177725166573738, 0.76104801430735, 0.8121293631535709, 0.8109592944389935, 0.6402387786100779, 0.8054244687254093, 0.446186016404363, 0.6395893916852341, 0.7189027914540884, 0.8430982815351713, 0.7681303441748624, 0.5934045290709786, 0.3943260889875841, 0.535538313838394, 0.49480246644993753, 0.7451912066962364], [0.788319132680411, 0.8470893568138963, 0.7371374775810814, 0.8177725166573739, 0.8444538552906871, 0.8127137658209571, 0.8379049368165173, 0.7776799463013793, 0.7270046587115854, 0.8175874743828098, 0.55410590222992, 0.7496463997608688, 0.7740864724823027, 0.8094976299956265, 0.8272708010021542, 0.7003652175102784, 0.5233250282413493, 0.6212349547656579, 0.6154976582879366, 0.8286228811428136], [0.7330304897324075, 0.827850124900962, 0.8033723833314276, 0.7610480143073499, 0.8127137658209571, 0.851014926259883, 0.8436560986003236, 0.760796092091283, 0.7769850590191049, 0.8269252040562066, 0.5953972716245122, 0.8162483329217788, 0.8094528469940412, 0.7951464927180801, 0.8374230266390615, 0.7519344581909412, 0.5842783991571706, 0.6622747669750165, 0.6581842976363442, 0.8944314041362246], [0.7775603589878508, 0.8635979389166458, 0.7506828197141612, 0.8121293631535709, 0.8379049368165172, 0.8436560986003236, 0.8598075537345222, 0.8029589391495592, 0.7388714370197983, 0.8458388965959397, 0.5379797169388211, 0.7703091068322433, 0.7975958322081067, 0.8403588684506071, 0.8338429646037864, 0.7015087800319021, 0.5113223455029358, 0.6216369683747096, 0.5999669466348323, 0.8709131408577749], [0.776281 ...

# %%
nodes_data = pd.read_csv("size.csv", header = None)
edges_data = pd.read_csv("edge.csv", index_col = 0)

m = np.shape(nodes_data)[0]
nodes = pd.DataFrame(index = list(range(m)), columns = ["id", "value", "category", "label"])

for i in range(m):
    nodes.iloc[i]["id"] = nodes_data.iloc[i][0]
    nodes.iloc[i]["category"] = nodes_data.iloc[i][0]
    nodes.iloc[i]["value"] = nodes_data.iloc[i][1]
    nodes.iloc[i]["label"] = nodes_data.iloc[i][0]

nodes.to_csv("nodes.csv", index = False)

# %%
total_edges, cnt = np.sum((edges_data.values != 0)[:]), 0
edges = pd.DataFrame(index = list(range(total_edges)), columns = ["source", "target", "weight"])

for g1 in genres:
    for g2 in genres:
        if edges_data.loc[g1][g2] != 0:
            edges.iloc[cnt]["source"] = g1
            edges.iloc[cnt]["target"] = g2
            edges.iloc[cnt]["weight"] = edges_data.loc[g1][g2]
            cnt += 1

edges.to_csv("edges.csv", index = False)

# %%
data = "["
node2idx = dict()
for i in range(m):
    data += "{\n"
    data += "name: \'" + nodes.iloc[i]["id"] + "\'\n}, "
    node2idx[nodes.iloc[i]["id"]] = str(i)
# print(data[:-2] + ']')
# print(node2idx)
"""
    source: 0,
    target: 1,
    symbolSize: [5, 20],
    label: {
        show: true
    },
    lineStyle: {
        width: 5,
        curveness: 0.2
    }
"""
# max_weight = edges.values[:, 2].astype(float).max()
links = "["
for i in range(total_edges):
    links += "{\n"
    links += "source: \'" + edges.iloc[i]["source"].replace('\'', '\\\'') + "\',\n"
    links += "target: \'" + edges.iloc[i]["target"].replace('\'', '\\\'') + "\',\n"
    links += "lineStyle: {\n\twidth: " + str(int(np.log(edges.values[i][2])* 2.5)) + ",\n\tcurveness: 0.2\n}\n}, "
    
print(links[:-2] + ']')
# Out:
# [{
# source: 'Electronic',
# target: 'R&B;',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Electronic',
# target: 'Pop/Rock',
# lineStyle: {
# 	width: 2.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Electronic',
# target: 'Latin',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Electronic',
# target: 'New Age',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Electronic',
# target: 'Classical',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Electronic',
# target: 'Stage & Screen',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'R&B;',
# target: 'Electronic',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'R&B;',
# target: 'Vocal',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'R&B;',
# target: 'Pop/Rock',
# lineStyle: {
# 	width: 11.0,
# 	curveness: 0.2
# }
# }, {
# source: 'R&B;',
# target: 'Religious',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'R&B;',
# target: 'Blues',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'R&B;',
# target: 'Country',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'R&B;',
# target: 'Jazz',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'R&B;',
# target: 'Latin',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'R&B;',
# target: 'New Age',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'R&B;',
# target: 'Folk',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'R&B;',
# target: 'International',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'R&B;',
# target: 'Reggae',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'R&B;',
# target: 'Comedy/Spoken',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'R&B;',
# target: 'Classical',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'R&B;',
# target: 'Avant-Garde',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Vocal',
# target: 'Electronic',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Vocal',
# target: 'R&B;',
# lineStyle: {
# 	width: 2.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Vocal',
# target: 'Pop/Rock',
# lineStyle: {
# 	width: 3.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Vocal',
# target: 'Religious',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Vocal',
# target: 'Blues',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Vocal',
# target: 'Country',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Vocal',
# target: 'Jazz',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Vocal',
# target: 'Latin',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Vocal',
# target: 'New Age',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Vocal',
# target: 'Folk',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Vocal',
# target: 'International',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Vocal',
# target: 'Reggae',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Vocal',
# target: 'Comedy/Spoken',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Vocal',
# target: 'Easy Listening',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Vocal',
# target: 'Classical',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Vocal',
# target: 'Stage & Screen',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Vocal',
# target: 'Children\'s',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Pop/Rock',
# target: 'Electronic',
# lineStyle: {
# 	width: 4.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Pop/Rock',
# target: 'R&B;',
# lineStyle: {
# 	width: 2.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Pop/Rock',
# target: 'Vocal',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Pop/Rock',
# target: 'Religious',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Pop/Rock',
# target: 'Blues',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Pop/Rock',
# target: 'Country',
# lineStyle: {
# 	width: 4.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Pop/Rock',
# target: 'Unknown',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Pop/Rock',
# target: 'Jazz',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Pop/Rock',
# target: 'Latin',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Pop/Rock',
# target: 'New Age',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Pop/Rock',
# target: 'Folk',
# lineStyle: {
# 	width: 2.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Pop/Rock',
# target: 'International',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Pop/Rock',
# target: 'Reggae',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Pop/Rock',
# target: 'Comedy/Spoken',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Pop/Rock',
# target: 'Easy Listening',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Pop/Rock',
# target: 'Classical',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Pop/Rock',
# target: 'Avant-Garde',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Pop/Rock',
# target: 'Stage & Screen',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Religious',
# target: 'R&B;',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Religious',
# target: 'Vocal',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Religious',
# target: 'Pop/Rock',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Religious',
# target: 'Country',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Religious',
# target: 'Folk',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Blues',
# target: 'Electronic',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Blues',
# target: 'R&B;',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Blues',
# target: 'Vocal',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Blues',
# target: 'Pop/Rock',
# lineStyle: {
# 	width: 5.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Blues',
# target: 'Religious',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Blues',
# target: 'Country',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Blues',
# target: 'Jazz',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Blues',
# target: 'Latin',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Blues',
# target: 'New Age',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Blues',
# target: 'Folk',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Blues',
# target: 'International',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Blues',
# target: 'Reggae',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Country',
# target: 'Electronic',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Country',
# target: 'R&B;',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Country',
# target: 'Vocal',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Country',
# target: 'Pop/Rock',
# lineStyle: {
# 	width: 4.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Country',
# target: 'Religious',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Country',
# target: 'Blues',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Country',
# target: 'Unknown',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Country',
# target: 'Jazz',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Country',
# target: 'Latin',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Country',
# target: 'New Age',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Country',
# target: 'Folk',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Country',
# target: 'International',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Country',
# target: 'Reggae',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Country',
# target: 'Comedy/Spoken',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Unknown',
# target: 'Pop/Rock',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Unknown',
# target: 'International',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Jazz',
# target: 'Electronic',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Jazz',
# target: 'R&B;',
# lineStyle: {
# 	width: 2.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Jazz',
# target: 'Vocal',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Jazz',
# target: 'Pop/Rock',
# lineStyle: {
# 	width: 3.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Jazz',
# target: 'Religious',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Jazz',
# target: 'Blues',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Jazz',
# target: 'Country',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Jazz',
# target: 'Latin',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Jazz',
# target: 'New Age',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Jazz',
# target: 'Folk',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Jazz',
# target: 'International',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Jazz',
# target: 'Reggae',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Jazz',
# target: 'Comedy/Spoken',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Jazz',
# target: 'Easy Listening',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Jazz',
# target: 'Classical',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Jazz',
# target: 'Avant-Garde',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Jazz',
# target: 'Stage & Screen',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Jazz',
# target: 'Children\'s',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Latin',
# target: 'Electronic',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Latin',
# target: 'R&B;',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Latin',
# target: 'Vocal',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Latin',
# target: 'Pop/Rock',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Latin',
# target: 'Religious',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Latin',
# target: 'Country',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Latin',
# target: 'Jazz',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Latin',
# target: 'New Age',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Latin',
# target: 'International',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Latin',
# target: 'Easy Listening',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Latin',
# target: 'Classical',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Latin',
# target: 'Stage & Screen',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'New Age',
# target: 'Electronic',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'New Age',
# target: 'Vocal',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'New Age',
# target: 'Pop/Rock',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'New Age',
# target: 'Jazz',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'New Age',
# target: 'Latin',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'New Age',
# target: 'Folk',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'New Age',
# target: 'International',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'New Age',
# target: 'Easy Listening',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'New Age',
# target: 'Classical',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'New Age',
# target: 'Stage & Screen',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Folk',
# target: 'Electronic',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Folk',
# target: 'R&B;',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Folk',
# target: 'Vocal',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Folk',
# target: 'Pop/Rock',
# lineStyle: {
# 	width: 4.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Folk',
# target: 'Religious',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Folk',
# target: 'Blues',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Folk',
# target: 'Country',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Folk',
# target: 'Jazz',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Folk',
# target: 'Latin',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Folk',
# target: 'New Age',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Folk',
# target: 'International',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Folk',
# target: 'Comedy/Spoken',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Folk',
# target: 'Classical',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'International',
# target: 'Electronic',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'International',
# target: 'R&B;',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'International',
# target: 'Vocal',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'International',
# target: 'Pop/Rock',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'International',
# target: 'Religious',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'International',
# target: 'Blues',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'International',
# target: 'Unknown',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'International',
# target: 'Jazz',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'International',
# target: 'Latin',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'International',
# target: 'New Age',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'International',
# target: 'Folk',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'International',
# target: 'Reggae',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'International',
# target: 'Easy Listening',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'International',
# target: 'Classical',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'International',
# target: 'Avant-Garde',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Reggae',
# target: 'Electronic',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Reggae',
# target: 'R&B;',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Reggae',
# target: 'Vocal',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Reggae',
# target: 'Pop/Rock',
# lineStyle: {
# 	width: 2.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Reggae',
# target: 'Latin',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Reggae',
# target: 'International',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Comedy/Spoken',
# target: 'Electronic',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Comedy/Spoken',
# target: 'R&B;',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Comedy/Spoken',
# target: 'Vocal',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Comedy/Spoken',
# target: 'Pop/Rock',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Comedy/Spoken',
# target: 'Country',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Comedy/Spoken',
# target: 'Folk',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Comedy/Spoken',
# target: 'Reggae',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Comedy/Spoken',
# target: 'Stage & Screen',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Comedy/Spoken',
# target: 'Children\'s',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Easy Listening',
# target: 'Vocal',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Easy Listening',
# target: 'Pop/Rock',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Easy Listening',
# target: 'Jazz',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Easy Listening',
# target: 'Latin',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Easy Listening',
# target: 'New Age',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Easy Listening',
# target: 'International',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Easy Listening',
# target: 'Avant-Garde',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Easy Listening',
# target: 'Stage & Screen',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Classical',
# target: 'Electronic',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Classical',
# target: 'Vocal',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Classical',
# target: 'Pop/Rock',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Classical',
# target: 'Country',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Classical',
# target: 'Jazz',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Classical',
# target: 'Latin',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Classical',
# target: 'New Age',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Classical',
# target: 'International',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Classical',
# target: 'Easy Listening',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Classical',
# target: 'Avant-Garde',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Classical',
# target: 'Stage & Screen',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Avant-Garde',
# target: 'Electronic',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Avant-Garde',
# target: 'Pop/Rock',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Avant-Garde',
# target: 'New Age',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Avant-Garde',
# target: 'Classical',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Avant-Garde',
# target: 'Stage & Screen',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Stage & Screen',
# target: 'Electronic',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Stage & Screen',
# target: 'Vocal',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Stage & Screen',
# target: 'Pop/Rock',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Stage & Screen',
# target: 'Country',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Stage & Screen',
# target: 'Jazz',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Stage & Screen',
# target: 'Folk',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Stage & Screen',
# target: 'International',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Stage & Screen',
# target: 'Easy Listening',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Stage & Screen',
# target: 'Classical',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Stage & Screen',
# target: 'Avant-Garde',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Stage & Screen',
# target: 'Children\'s',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }, {
# source: 'Children\'s',
# target: 'Pop/Rock',
# lineStyle: {
# 	width: 1.0,
# 	curveness: 0.2
# }
# }]

# %%
print('\\\'')
# Out:
# \'

# %%
genre_embedding = pd.DataFrame(np.zeros((n_genres, 3)), index = genres, columns = ['Component_'+str(i) for i in [0, 1, 2]])
for g in genres:
    embedding = []
    for x in genre_dict[g]:
        embedding.append(musician_embedding[x])
    genre_embedding.loc[g] = np.mean(embedding, axis = 0)
# Out:
#                 Component_0  Component_1  Component_2
# Electronic        -0.496701     0.438944     0.902157
# R&B;              -0.114112    -0.298396     0.299866
# Vocal              0.905649     0.019567     0.693069
# Pop/Rock          -0.525564     0.281142     0.572945
# Religious         -0.048179     0.469127     0.326344
# Blues              0.250609    -0.626238     0.793990
# Country            0.009845    -0.331292     0.370748
# Unknown           -0.538553    -0.844974     0.743554
# Jazz               0.608653    -0.133595     1.673655
# Latin             -0.197530    -0.558198     0.452538
# New Age            1.168233     0.846596     2.629171
# Folk               0.842022    -0.220736     0.913249
# International      0.252239    -0.380122     1.007278
# Reggae            -0.135869    -0.836779     0.310615
# Comedy/Spoken     -0.226518     0.352446     1.638490
# Easy Listening     0.646961     0.306351     1.580227
# Classical          1.359179     0.811267     2.675255
# Avant-Garde        0.983206     0.287062     2.892027
# Stage & Screen     1.027174     0.823946     1.874427
# Children's         0.497450    -0.676515     0.234190

# %%
x_axis = range(1920, 2010, 10)

for j in [0, 1, 2, 3]:
    plt.figure(j)
    for g in genres[5*j : 5*j+5]:
        if g == "Unknown":
            continue
        y_axis = genre_scale_evolve.loc[g]
        plt.plot(x_axis, y_axis, '--o', linewidth = 2.5, markersize = 6, label = g)
    plt.xlabel("Decade", fontsize = 18)
    plt.ylabel("Number of Works", fontsize = 18)
    plt.grid(True, linestyle = '--')
    plt.tick_params(labelsize = 18)
    plt.legend(loc = 2, bbox_to_anchor = (1.05, 1.0), borderaxespad = 0, fontsize = 18)
plt.show()

# %%
temp = raw_full_data["release_date"].values
temp = temp.reshape((temp.shape[0], 1))
X_ = MinMaxScaler().fit_transform(raw_full_data[info_columns].values)
Z_ = dimension_reducer.transform(X_)
new_data = np.hstack((temp, np.reshape(genre_list, (len(genre_list), 1)).astype(object), Z_))

new_data = pd.DataFrame(new_data, index = raw_full_data.index, \
                        columns = ["release_date", "genre"] + ["Components_"+str(i) for i in [0, 1, 2]], dtype = object)

# %%
genre_work_evolve = pd.DataFrame(np.zeros((n_genres, 9)), index = genres, columns = list(range(1920, 2010, 10)))

for decade, table in new_data.groupby("release_date"):
    for g in genres:
        genre_work_evolve.loc[g][decade] = np.shape(table[table["genre"] == g])[0]

genre_work_evolve
# Out:
#                  1920   1930   1940    1950    1960     1970     1980    1990  \
# Electronic       50.0    0.0   12.0    10.0     5.0     86.0     63.0   347.0
# R&B;            105.0    2.0    7.0   393.0  1676.0   2299.0   1419.0  1608.0
# Vocal             9.0  669.0  547.0  2379.0  1396.0    235.0    228.0   215.0
# Pop/Rock        210.0    9.0   91.0   391.0  5833.0  10600.0  10391.0  7321.0
# Religious         8.0    0.0    1.0    41.0    16.0     15.0     83.0   148.0
# Blues             6.0   65.0  150.0   185.0   461.0    177.0     94.0    82.0
# Country          28.0   51.0   64.0   651.0  1242.0   1211.0   1098.0  1217.0
# Unknown         430.0   62.0  101.0   203.0   241.0    192.0    317.0   282.0
# Jazz              9.0  138.0  216.0  3105.0  1948.0    538.0    401.0   259.0
# Latin            74.0    1.0  123.0   307.0   510.0    503.0    833.0  1191.0
# New Age           0.0    0.0   16.0     0.0     1.0     12.0     97.0    91.0
# Folk              0.0    0.0   18.0   273.0   588.0    290.0     49.0    70.0
# International     0.0   17.0  204.0   460.0   183.0    159.0    233.0   124.0
# Reggae            2.0   42.0   69.0    24.0   140.0    422.0    260.0   169.0
# Comedy/Spoken     0.0    0.0    3.0    62.0   104.0     32.0     67.0    28.0
# Easy Listening    0.0    0.0   22.0   390.0   353.0     22.0     14.0     6.0
# Classical         8.0  144.0  462.0  1072.0   326.0     81.0    136.0    84.0
# Avant-Garde       1.0    3.0   41.0    75.0    58.0      6.0     30.0    15.0
# Stage & Screen    1.0    9.0  157.0   121.0   154.0     68.0    138.0   159.0
# Children's        0.0    0.0    0.0     0.0    34.0      7.0      0.0     3.0
#
#                   2000
# Electronic       325.0
# R&B;            1737.0
# Vocal            465.0
# Pop/Rock        8102.0
# Religious        228.0
# Blues             34.0
# Country         1176.0
# Unknown          192.0
# Jazz             277.0
# Latin            741.0
# New Age           50.0
# Folk              82.0
# International     72.0
# Reggae           222.0
# Comedy/Spoken     25.0
# Easy Listening     5.0
# Classical         40.0
# Avant-Garde       10.0
# Stage & Screen   203.0
# Children's        10.0

# %%
x_axis = range(1920, 2010, 10)

for j in [0, 1, 2, 3]:
    plt.figure(j)
    for g in genres[5*j : 5*j+5]:
        if g == "Unknown":
            continue
        y_axis = genre_work_evolve.loc[g]
        plt.plot(x_axis, y_axis, '--o', linewidth = 2.5, markersize = 6, label = g)
    plt.xlabel("Decade", fontsize = 18)
    plt.ylabel("Number of Works", fontsize = 18)
    plt.grid(True, linestyle = '--')
    plt.tick_params(labelsize = 18)
    plt.legend(loc = 2, bbox_to_anchor = (1.05, 1.0), borderaxespad = 0, fontsize = 18)
plt.show()

# %%
genre_feature_evolve = pd.DataFrame(index = genres, columns = ["Component_"+str(i) for i in [0, 1, 2]], dtype = object)
for i in genre_feature_evolve.index:
    for j in genre_feature_evolve.columns:
        genre_feature_evolve.loc[i][j] = []

for decade, table in new_data.groupby("release_date"):
    for g in genres:
        temp = table[table["genre"] == g][["Components_"+str(i) for i in [0, 1, 2]]]
        # print(np.mean(temp.values.astype(float), axis = 0))
        if np.shape(temp)[0] != 0:
            embedding = np.mean(temp.values.astype(float), axis = 0)
            for i in range(3):
                genre_feature_evolve.loc[g]["Component_"+str(i)].append(embedding[i])
        else:
            for i in range(3):
                genre_feature_evolve.loc[g]["Component_"+str(i)].append(np.nan)

# %%
for i in genre_feature_evolve.columns:
    for j in genre_feature_evolve.index:
        l = len(genre_feature_evolve[i][j])
        for k in range(l):
            if k > 0 and k < l and genre_feature_evolve[i][j][k] is np.nan:
                genre_feature_evolve[i][j][k] = (genre_feature_evolve[i][j][k-1] + genre_feature_evolve[i][j][k+1]) / 2

# %%
x_axis = list(range(1920, 2011, 10))

for i in [0, 1, 2]:
    for j in [0, 1, 2, 3]:
        plt.figure(4*i+j)
        for g in genres[5*j : 5*j+5]:
            if g == "Unknown":
                continue
            y_axis = genre_feature_evolve.loc[g]["Component_"+str(i)]
            plt.plot(x_axis, y_axis, '--o', linewidth = 2.5, markersize = 6, label = g)
        plt.xlabel("Decade", fontsize = 18)
        plt.ylabel("Component "+str(i), fontsize = 18)
        plt.grid(True, linestyle = '--')
        plt.tick_params(labelsize = 18)
        plt.legend(loc = 2, bbox_to_anchor = (1.05, 1.0), borderaxespad = 0, fontsize = 16)
plt.show()
