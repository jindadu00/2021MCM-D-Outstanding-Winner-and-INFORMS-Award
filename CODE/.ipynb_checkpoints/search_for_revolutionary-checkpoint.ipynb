# %%
import numpy as np
import pandas as pd
import networkx as nx

# %%
full_music_data = pd.read_csv('full_music_data.csv')

# %%
influence_data = pd.read_csv('influence_data.csv')
G=nx.DiGraph()
for index, row in influence_data.iterrows():
    G.add_edge(row.influencer_id, row.follower_id)

# %%
full_music_data = full_music_data[1964<=full_music_data.year]
full_music_data = full_music_data[1966>=full_music_data.year]
full_music_data
# Out:
#            artist_names artists_id  danceability  energy  valence    tempo  \
# 21      ["Anita O'Day"]   [479028]         0.502  0.1110    0.459  115.410
# 33      ["Anita O'Day"]   [479028]         0.261  0.1060    0.108   76.930
# 43      ["Anita O'Day"]   [479028]         0.400  0.0663    0.233  109.202
# 44      ["Anita O'Day"]   [479028]         0.687  0.2800    0.741   87.618
# 47      ["Anita O'Day"]   [479028]         0.627  0.2740    0.691  116.982
# ...                 ...        ...           ...     ...      ...      ...
# 97991  ['Yusef Lateef']   [596922]         0.493  0.6030    0.500   96.735
# 97992  ['Yusef Lateef']   [596922]         0.620  0.1990    0.603  102.766
# 97993  ['Yusef Lateef']   [596922]         0.449  0.3600    0.193   78.916
# 98014  ['Yves Montand']   [695189]         0.291  0.1420    0.270  110.683
# 98038  ['Yves Montand']   [695189]         0.503  0.2180    0.399  109.578
#
#        loudness  mode  key  acousticness  instrumentalness  liveness  \
# 21      -18.550     1    2         0.892          0.000020    0.3500
# 33      -14.410     1   10         0.974          0.003350    0.1710
# 43      -22.418     1   10         0.897          0.000002    0.1720
# 44      -17.572     1    2         0.778          0.000000    0.0631
# 47      -13.423     0    2         0.862          0.000000    0.2420
# ...         ...   ...  ...           ...               ...       ...
# 97991   -10.919     0    1         0.805          0.003670    0.1070
# 97992   -18.933     0    7         0.986          0.825000    0.1250
# 97993   -17.882     1    7         0.992          0.888000    0.1570
# 98014   -16.337     1    8         0.943          0.000011    0.1210
# 98038   -14.742     1    8         0.860          0.000000    0.1720
#
#        speechiness  explicit  duration_ms  popularity  year release_date  \
# 21          0.0606         0       148187          18  1961    3/14/1961
# 33          0.0358         0       263333          13  1962     1/1/1962
# 43          0.0489         0       182413          13  1961    3/14/1961
# 44          0.0534         0       158947          16  1962     1/1/1962
# 47          0.0819         0       148973          11  1961     1/1/1961
# ...            ...       ...          ...         ...   ...          ...
# 97991       0.0320         0       336533          27  1961         1961
# 97992       0.1160         0       138427          25  1961         1961
# 97993       0.2100         0       207440          29  1966     1/1/1966
# 98014       0.0365         0       196867          31  1964    1/20/1964
# 98038       0.0403         0       211707          44  1964    1/20/1964
#
#                                    song_title (censored)
# 21                                      That Old Feeling
# 33                       The Ballad Of The Sad Young Men
# 43                                  When Sunny Gets ****
# 44                       You And The ***** And The Music
# 47                        What A Little Moonlight Can Do
# ...                                                  ...
# 97991                   Snafu - Rudy Van Gelder Remaster
# 97992  The ***** Faces Of Balal - Rudy Van Gelder Rem...
# 97993                                   First Gymnopedie
# 98014                                     La vie en rose
# 98038                                       C'est si bon
#
# [9344 rows x 19 columns]

# %%
candidates = set()
for index, row in full_music_data.iterrows():
    candidate =[int(i) for i in row.artists_id[1:-1].split(', ')]

    candidates = candidates | set(candidate)

candidates = candidates & set(G.nodes())

# %%
eliminated = set()
for data in candidates:
    eliminated = eliminated | set(G[data])

# %%
left_candidates = candidates - eliminated

# %%
and_score = pd.read_csv('and_score.csv',index_col=0,encoding='ISO-8859-1')

# %%
and_score
# Out:
#                              name        genre  descendants  \
# artist_id
# 754032                The Beatles     Pop/Rock         3758
# 423829                Miles Davis         Jazz         3588
# 583959              Willie Nelson      Country         1453
# 102050          The Kingston Trio         Folk         2195
# 33161      Sly & the Family Stone         R&B;         2932
# ...                           ...          ...          ...
# 833539              Mark Morrison         R&B;            0
# 847703                 Jerry Ross     Pop/Rock            0
# 921888                  Alborosie       Reggae            0
# 943649             Morton Feldman  Avant-Garde            0
# 3306945                Kaytranada   Electronic            0
#
#            betweenness_centrality  eigenvector_centrality  genres_diversity  \
# artist_id
# 754032                   0.017854            2.480000e-05                18
# 423829                   0.024155            2.090000e-05                18
# 583959                   0.037038            3.112440e-04                14
# 102050                   0.029905            3.050000e-05                16
# 33161                    0.021835            4.640000e-05                18
# ...                           ...                     ...               ...
# 833539                   0.000000            2.120000e-28                 0
# 847703                   0.000000            2.120000e-28                 0
# 921888                   0.000000            2.120000e-28                 0
# 943649                   0.000000            2.120000e-28                 0
# 3306945                  0.000000            2.120000e-28                 0
#
#            influence_by_loyalty         score
# artist_id
# 754032                72.915701  5.871181e-01
# 423829                19.533789  5.205012e-01
# 583959                 5.200698  4.790636e-01
# 102050                 2.317591  4.575855e-01
# 33161                  6.813955  4.439420e-01
# ...                         ...           ...
# 833539                 0.000000  3.370000e-28
# 847703                 0.000000  3.370000e-28
# 921888                 0.000000  3.370000e-28
# 943649                 0.000000  3.370000e-28
# 3306945                0.000000  3.370000e-28
#
# [5603 rows x 8 columns]

# %%
ccc=[]
Index=[]
for candidate in left_candidates:
    ccc.append(and_score.loc[candidate,'score'])
    Index.append(candidate)
print(ccc.index(max(ccc)))
print(ccc[49])
print(Index[49])
# Out:
# 49
# 0.296099601
# 317093

# %%
and_score.loc[317093,'name']
# Out:
# 'Nat King Cole'

# %%
influence_data[influence_data.follower_id==754032]
# Out:
#        influencer_id                 influencer_name influencer_main_genre  \
# 31334          29334                    Slim Whitman               Country
# 31335          35021  Smokey Robinson & the Miracles                  R&B;
# 31336          38490                        The Band              Pop/Rock
# 31337          46699             The Everly Brothers              Pop/Rock
# 31338          55128                      Bo Diddley              Pop/Rock
# 31339          66915                       Bob Dylan              Pop/Rock
# 31340          90803                     King Curtis                  R&B;
# 31341         117001                  Barrett Strong                  R&B;
# 31342         120521                     Chuck Berry              Pop/Rock
# 31343         135024                  Larry Williams                  R&B;
# 31344         137494                     Fats Domino                  R&B;
# 31345         174557                     Carole King              Pop/Rock
# 31346         180228                   Elvis Presley              Pop/Rock
# 31347         239961       Johnny Kidd & the Pirates              Pop/Rock
# 31348         269972              Little Willie John                  R&B;
# 31349         279141                  Ritchie Valens              Pop/Rock
# 31350         332141                 Jerry Lee Lewis              Pop/Rock
# 31351         376608                 The Marvelettes                  R&B;
# 31352         404463                    Ravi Shankar         International
# 31353         418981                   The Shirelles                  R&B;
# 31354         477875                    The Supremes                  R&B;
# 31355         496405                     The Shadows              Pop/Rock
# 31356         538677                     Buddy Holly              Pop/Rock
# 31357         766893              The Isley Brothers                  R&B;
# 31358         792953                    Carl Perkins              Pop/Rock
# 31359         793988                   Eddie Cochran              Pop/Rock
# 31360         803720                    Gene Vincent              Pop/Rock
# 31361         821571                 Smokey Robinson                  R&B;
# 31362         824022                  Little Richard              Pop/Rock
# 31363         852007                     Roy Orbison              Pop/Rock
# 31364         941579                      Buck Owens               Country
#
#        influencer_active_start  follower_id follower_name follower_main_genre  \
# 31334                     1940       754032   The Beatles            Pop/Rock
# 31335                     1950       754032   The Beatles            Pop/Rock
# 31336                     1960       754032   The Beatles            Pop/Rock
# 31337                     1950       754032   The Beatles            Pop/Rock
# 31338                     1940       754032   The Beatles            Pop/Rock
# 31339                     1960       754032   The Beatles            Pop/Rock
# 31340                     1950       754032   The Beatles            Pop/Rock
# 31341                     1950       754032   The Beatles            Pop/Rock
# 31342                     1950       754032   The Beatles            Pop/Rock
# 31343                     1950       754032   The Beatles            Pop/Rock
# 31344                     1940       754032   The Beatles            Pop/Rock
# 31345                     1950       754032   The Beatles            Pop/Rock
# 31346                     1950       754032   The Beatles            Pop/Rock
# 31347                     1960       754032   The Beatles            Pop/Rock
# 31348                     1950       754032   The Beatles            Pop/Rock
# 31349                     1950       754032   The Beatles            Pop/Rock
# 31350                     1950       754032   The Beatles            Pop/Rock
# 31351                     1960       754032   The Beatles            Pop/Rock
# 31352                     1930       754032   The Beatles            Pop/Rock
# 31353                     1950       754032   The Beatles            Pop/Rock
# 31354                     1950       754032   The Beatles            Pop/Rock
# 31355                     1950       754032   The Beatles            Pop/Rock
# 31356                     1950       754032   The Beatles            Pop/Rock
# 31357                     1950       754032   The Beatles            Pop/Rock
# 31358                     1950       754032   The Beatles            Pop/Rock
# 31359                     1950       754032   The Beatles            Pop/Rock
# 31360                     1950       754032   The Beatles            Pop/Rock
# 31361                     1950       754032   The Beatles            Pop/Rock
# 31362                     1950       754032   The Beatles            Pop/Rock
# 31363                     1950       754032   The Beatles            Pop/Rock
# 31364                     1940       754032   The Beatles            Pop/Rock
#
#        follower_active_start
# 31334                   1960
# 31335                   1960
# 31336                   1960
# 31337                   1960
# 31338                   1960
# 31339                   1960
# 31340                   1960
# 31341                   1960
# 31342                   1960
# 31343                   1960
# 31344                   1960
# 31345                   1960
# 31346                   1960
# 31347                   1960
# 31348                   1960
# 31349                   1960
# 31350                   1960
# 31351                   1960
# 31352                   1960
# 31353                   1960
# 31354                   1960
# 31355                   1960
# 31356                   1960
# 31357                   1960
# 31358                   1960
# 31359                   1960
# 31360                   1960
# 31361                   1960
# 31362                   1960
# 31363                   1960
# 31364                   1960
