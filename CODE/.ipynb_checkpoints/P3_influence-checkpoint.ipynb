# %%
import networkx as nx
import pandas as pd

# %%
data = pd.read_csv('influence_data.csv')

# %%
data
# Out:
#        influencer_id  influencer_name influencer_main_genre  \
# 0             759491    The Exploited              Pop/Rock
# 1              25462           Tricky            Electronic
# 2              66915        Bob Dylan              Pop/Rock
# 3              71209    Leonard Cohen              Pop/Rock
# 4              91438     The Gun Club              Pop/Rock
# ...              ...              ...                   ...
# 42765         580300   Sufjan Stevens              Pop/Rock
# 42766         261309      Vybz Kartel                Reggae
# 42767         467203  Michael Jackson                  R&B;
# 42768        2518003          Popcaan                Reggae
# 42769        2896351        Tommy Lee                Reggae
#
#        influencer_active_start  follower_id      follower_name  \
# 0                         1980           74     Special Duties
# 1                         1990          335          PJ Harvey
# ...

# %%
genres=set(data['influencer_main_genre'])
edge=pd.DataFrame(index=genres,columns=genres,dtype=float).fillna(value = 0)
size=pd.DataFrame(index=genres,columns=['size'],dtype=float).fillna(value = 0)

# %%
G=nx.DiGraph()
for index, row in data.iterrows():
    if row['influencer_main_genre']!=row['follower_main_genre']:
        edge.loc[row.influencer_main_genre,row.follower_main_genre]=edge.loc[row.influencer_main_genre,row.follower_main_genre]+1
    else:
        size.loc[row.influencer_main_genre,'size']=size.loc[row.influencer_main_genre,'size']+1

# %%
size
# Out:
#                    size
# Blues             372.0
# Comedy/Spoken     101.0
# Jazz             1769.0
# Unknown             0.0
# R&B;             3384.0
# Country          2502.0
# Pop/Rock        22049.0
# Reggae            584.0
# Stage & Screen     80.0
# Folk              271.0
# New Age            47.0
# Easy Listening     18.0
# Vocal             537.0
# Avant-Garde         7.0
# Classical          17.0
# Children's          2.0
# Latin             405.0
# Religious         155.0
# Electronic        372.0
# International      81.0

# %%
size.to_csv('size.csv')
edge.to_csv('edge.csv')
